# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("finalinfoDf.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                         keyword_view_resource_name  \
# 0           0  customers/9025864929/keywordViews/107128554236...
# 1           1  customers/9025864929/keywordViews/110429922674...
# 2           2  customers/9025864929/keywordViews/107073070213...
# 3           3  customers/9025864929/keywordViews/104529020302...
# 4           4  customers/9025864929/keywordViews/104529020302...
#
#                             keyword_text       campaign_name ad_group_name  \
# 0                            Accountancy  AUS - Australia #1    Accountant
# 1                   Melbourne Accountant  VIC - Melbourne #1    Accountant
# 2                   Adelaide Accountancy   SA  - Adelaide #1    Accountant
# 3                    Canberra Accountant   ACT - Canberra #1    Accountant
# 4  Finance Canberra Recruitment Agencies   ACT - Canberra #1    Accountant
#
#    campaign_status  ad_group_criterion_status  \
# 0              2.0                        2.0
# 1              2.0                        2.0
# 2              2.0                        2.0
# 3              2.0                        2.0
# 4              2.0                        2.0
#
#                            ad_group_campaign  impressions   max_cpc  ...  \
# 0  customers/9025864929/campaigns/1652295787       1085.0  110000.0  ...
# 1  customers/9025864929/campaigns/1652295790        334.0  390000.0  ...
# 2  customers/9025864929/campaigns/1652295781        100.0  310000.0  ...
# 3    customers/9025864929/campaigns/45496181         76.0  620000.0  ...
# 4    customers/9025864929/campaigns/45496181         35.0  620000.0  ...
#
#    all_conversions   ad_group_id   campaign_id  clicks  cost_micros  \
# 0              1.0  1.071286e+11  1.652296e+09    12.0  141150000.0
# 1              0.0  1.104299e+11  1.652296e+09    11.0  136280000.0
# 2              0.0  1.070731e+11  1.652296e+09     2.0   24310000.0
# 3              0.0  1.045290e+11  4.549618e+07     4.0   13210000.0
# 4              1.0  1.045290e+11  4.549618e+07     3.0    7990000.0
#
#     average_cpc  campaign_start_date  \
# 0  1.176250e+07           2018-12-10
# 1  1.238909e+07           2018-12-10
# 2  1.215500e+07           2018-12-10
# 3  3.302500e+06           2010-02-01
# 4  2.663333e+06           2010-02-01
#
#                       campaign_resource_name  Category  \
# 0  customers/9025864929/campaigns/1652295787     Other
# 1  customers/9025864929/campaigns/1652295790     Other
# 2  customers/9025864929/campaigns/1652295781     Other
# 3    customers/9025864929/campaigns/45496181     Other
# 4    customers/9025864929/campaigns/45496181     Other
#
#         primaryCampaignName
# 0  AUS - Australia #1#Other
# 1  VIC - Melbourne #1#Other
# 2   SA  - Adelaide #1#Other
# 3   ACT - Canberra #1#Other
# 4   ACT - Canberra #1#Other
#
# [5 rows x 25 columns]

# %%
overallTocreate = []
    alreadyCreatedCampaign = {}
    for eachcampaign in df.primaryCampaignName.unique():
        unique_ad_group_list = df.loc[df.primaryCampaignName == eachcampaign, "ad_group_name"].unique()
        print(eachcampaign)
        print(alreadyCreatedCampaign)
        for each_ad_group in unique_ad_group_list:
            overallTocreatedict = {}
            _, low, mid, high = df.loc[(df.primaryCampaignName == eachcampaign) &
                                       (df.ad_group_name == each_ad_group), "clicks"].quantile([0, 0.20, 0.40, 1])
            if low == mid == high:
                overallTocreatedict["campaign_name"] = eachcampaign
                overallTocreatedict["ad_group_name"] = each_ad_group + "#Common"
                overallTocreatedict["KeywordList"] = list(df.loc[(df.primaryCampaignName == eachcampaign) &
                                                                 (df.ad_group_name == each_ad_group), "keyword_text"].values)
                overallTocreatedict["Bid"] = 500000
                overallTocreatedict["campaign_budget_name"] = overallTocreatedict["campaign_name"] + "#Budget"
                if overallTocreatedict["campaign_name"] not in alreadyCreatedCampaign.keys():
                    overallTocreatedict["campaign_id"] = \
                        campnew.create_campaign(campaign_budget_name= overallTocreatedict["campaign_budget_name"],
                                                campaign_budget_value=50000000,
                                                campaign_name=overallTocreatedict["campaign_name"])["campaign_id"]
                    overallTocreatedict["campaign_created"] = True
                    alreadyCreatedCampaign[overallTocreatedict["campaign_name"]] = overallTocreatedict["campaign_id"]
                else:
                    overallTocreatedict["campaign_id"] = alreadyCreatedCampaign[overallTocreatedict["campaign_name"]]
                overallTocreatedict["group_id"] = campnew.create_ad_group(campaign_id=overallTocreatedict["campaign_id"],
                                                                  ad_group_name=overallTocreatedict["ad_group_name"],
                                                                  bid_amount=overallTocreatedict["Bid"])["ad_group_id"]
                overallTocreatedict["Add_group_created"] = True
                for keyword in overallTocreatedict["KeywordList"]:
                    campnew.add_keywords(ad_group_id=overallTocreatedict["group_id"],
                                         keyword_text=keyword)
                overallTocreate.append(overallTocreatedict)

            else:
                lowList = list(df.loc[(df.primaryCampaignName == eachcampaign) &
                                      (df.ad_group_name == each_ad_group) &
                                      (df.clicks <= low), "keyword_text"].values)
                midList = list(df.loc[(df.primaryCampaignName == eachcampaign) &
                                      (df.ad_group_name == each_ad_group) &
                                      (df.clicks > low) & (df.clicks <= mid), "keyword_text"].values)
                highList = list(df.loc[(df.primaryCampaignName == eachcampaign) &
                                       (df.ad_group_name == each_ad_group) &
                                       (df.clicks > mid), "keyword_text"].values)

                if len(lowList) > 0:
                    overallTocreatedict["campaign_name"] = eachcampaign
                    overallTocreatedict["ad_group_name"] = each_ad_group + "#Low"
                    overallTocreatedict["KeywordList"] = lowList
                    overallTocreatedict["Bid"] = 500000
                    overallTocreatedict["campaign_budget_name"] = overallTocreatedict["campaign_name"] + "#Budget"
                    if overallTocreatedict["campaign_name"] not in alreadyCreatedCampaign.keys():
                        overallTocreatedict["campaign_id"] = \
                        campnew.create_campaign(campaign_budget_name=overallTocreatedict["campaign_budget_name"],
                                        campaign_budget_value=50000000,
                                        campaign_name=overallTocreatedict["campaign_name"])["campaign_id"]
                        overallTocreatedict["campaign_created"] = True
                        alreadyCreatedCampaign[overallTocreatedict["campaign_name"]] = overallTocreatedict["campaign_id"]
                    else:
                        overallTocreatedict["campaign_id"] = alreadyCreatedCampaign[overallTocreatedict["campaign_name"]]
                    overallTocreatedict["group_id"] = campnew.create_ad_group(campaign_id=overallTocreatedict["campaign_id"],
                                                                      ad_group_name=overallTocreatedict["ad_group_name"],
                                                                      bid_amount=overallTocreatedict["Bid"])["ad_group_id"]
                    overallTocreatedict["Add_group_created"] = True
                    for keyword in overallTocreatedict["KeywordList"]:
                        campnew.add_keywords(ad_group_id=overallTocreatedict["group_id"],
                                             keyword_text=keyword)
                    overallTocreate.append(overallTocreatedict)
                if len(midList) > 0:
                    overallTocreatedict["campaign_name"] = eachcampaign
                    overallTocreatedict["ad_group_name"] = each_ad_group + "#Mid"
                    overallTocreatedict["KeywordList"] = midList
                    overallTocreatedict["Bid"] = 600000
                    overallTocreatedict["campaign_budget_name"] = overallTocreatedict["campaign_name"] + "#Budget"
                    if overallTocreatedict["campaign_name"] not in alreadyCreatedCampaign.keys():
                        overallTocreatedict["campaign_id"] = \
                        campnew.create_campaign(campaign_budget_name=overallTocreatedict["campaign_budget_name"],
                                        campaign_budget_value=50000000,
                                        campaign_name=overallTocreatedict["campaign_name"])["campaign_id"]
                        overallTocreatedict["campaign_created"] = True
                        alreadyCreatedCampaign[overallTocreatedict["campaign_name"]] = overallTocreatedict["campaign_id"]
                    else:
                        overallTocreatedict["campaign_id"] = alreadyCreatedCampaign[overallTocreatedict["campaign_name"]]
                    overallTocreatedict["group_id"] = campnew.create_ad_group(campaign_id=overallTocreatedict["campaign_id"],
                                                                      ad_group_name=overallTocreatedict["ad_group_name"],
                                                                      bid_amount=overallTocreatedict["Bid"])["ad_group_id"]
                    overallTocreatedict["Add_group_created"] = True
                    for keyword in overallTocreatedict["KeywordList"]:
                        campnew.add_keywords(ad_group_id = overallTocreatedict["group_id"],
                                             keyword_text = keyword)
                    overallTocreate.append(overallTocreatedict)
                if len(highList) > 0:
                    overallTocreatedict["campaign_name"] = eachcampaign
                    overallTocreatedict["ad_group_name"] = each_ad_group + "#High"
                    overallTocreatedict["KeywordList"] = highList
                    overallTocreatedict["Bid"] = 1200000
                    overallTocreatedict["campaign_budget_name"] = overallTocreatedict["campaign_name"] + "#Budget"
                    if overallTocreatedict["campaign_name"] not in alreadyCreatedCampaign.keys():
                        overallTocreatedict["campaign_id"] = \
                            campnew.create_campaign(campaign_budget_name=overallTocreatedict["campaign_budget_name"],
                                                    campaign_budget_value=50000000,
                                                    campaign_name=overallTocreatedict["campaign_name"])["campaign_id"]
                        overallTocreatedict["campaign_created"] = True
                        alreadyCreatedCampaign[overallTocreatedict["campaign_name"]] = overallTocreatedict["campaign_id"]
                    else:
                        overallTocreatedict["campaign_id"] = alreadyCreatedCampaign[overallTocreatedict["campaign_name"]]
                    overallTocreatedict["group_id"] = campnew.create_ad_group(campaign_id=overallTocreatedict["campaign_id"],
                                                                      ad_group_name=overallTocreatedict["ad_group_name"],
                                                                      bid_amount=overallTocreatedict["Bid"])["ad_group_id"]
                    overallTocreatedict["Add_group_created"] = True
                    for keyword in overallTocreatedict["KeywordList"]:
                        campnew.add_keywords(ad_group_id=overallTocreatedict["group_id"],
                                             keyword_text=keyword)
                    overallTocreate.append(overallTocreatedict)
            pd.DataFrame(overallTocreate).to_csv("overallTocreate.csv")
